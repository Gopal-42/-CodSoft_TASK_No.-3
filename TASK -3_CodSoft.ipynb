# %%
# TASK-2 - CREDIT CARD FRAUD DETECTION

# Author: Gopal Krishna

# Batch: June A58

# Domain: Data Science

# Aim: Build a model that predicts the fraudulent credit card transactions.

# %% [markdown]
# *Importing Important Libraries*

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# *Importing DATASET*

# %%
data_cc = pd.read_csv("/content/creditcard.csv")
data_cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data_cc.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 81294  58872  1.104942 -0.900171  0.271719 -0.528821 -1.064148 -0.533231
# 81295  58872 -0.438214  0.492120  2.440138  0.454998 -0.148495  0.476077
# 81296  58872 -0.473593  1.109975  1.704117 -0.019309  0.076774 -0.585510
# 81297  58873 -2.769864  1.253167  0.752106  0.455407 -1.894425  0.539661
# 81298  58874  1.116529 -0.157694 -0.149952  1.059937  0.256352       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 81294 -0.366603 -0.121795 -0.855554  ... -0.384664 -0.898500  0.062703
# 81295  0.115241  0.232635 -0.057007  ...  0.263317  0.865982 -0.093755
# 81296  0.718295 -0.023019 -0.619852  ... -0.165078 -0.312285  0.027214
# 81297  1.081240 -0.188369  1.288851  ... -0.139859  0.276332  0.232680
# 81298       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
data_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81299 entries, 0 to 81298
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    81299 non-null  int64
#  1   V1      81299 non-null  float64
#  2   V2      81299 non-null  float64
#  3   V3      81299 non-null  float64
#  4   V4      81299 non-null  float64
#  5   V5      81299 non-null  float64
#  6   V6      81298 non-null  float64
#  7   V7      81298 non-null  float64
#  8   V8      81298 non-null  float64
#  9   V9      81298 non-null  float64
#  10  V10     81298 non-null  float64
#  11  V11     81298 non-null  float64
#  12  V12     81298 non-null  float64
#  13  V13     81298 non-null  float64
#  14  V14     81298 non-null  float64
#  15  V15     81298 non-null  float64
#  16  V16     81298 non-null  float64
#  17  V17     81298 non-null  float64
#  18  V18     81298 non-null  float64
#  19  V19     81298 non-null  float64
# ...

# %%
data_cc.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# **Distribution of transactions**

# %%
data_cc['Class'].value_counts()
# Out:
# Class
# 0.0    81100
# 1.0      198
# Name: count, dtype: int64

# %% [markdown]
# *DATASET Analysing*

# %% [markdown]
# 0=> Normal Transaction
# 1=> Fraudulent Transaction

# %%
legit = data_cc[data_cc.Class == 0]
fraud = data_cc[data_cc.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (81100, 31)
# (198, 31)

# %%
legit.Amount.describe()
# Out:
# count    81100.000000
# mean        98.107837
# std        269.738371
# min          0.000000
# 25%          7.730000
# 50%         26.990000
# 75%         89.530000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     198.000000
# mean       93.992778
# std       211.099415
# min         0.000000
# 25%         1.000000
# 50%         6.410000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values of both transactions
data_cc.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    37682.000937 -0.244848 -0.049587  0.701227  0.150821 -0.266673
# 1.0    33363.156566 -6.471142  4.615004 -8.642655  5.163640 -4.726320
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.100652 -0.097695  0.045923 -0.005120  ...  0.041506 -0.031324
# 1.0   -1.982527 -6.839513  3.005157 -3.106588  ...  0.381224  0.754921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.104952 -0.037601  0.008468  0.134375  0.025923  0.000776  0.002077
# 1.0   -0.156429 -0.222226 -0.092181  0.229928  0.089311  0.568505  0.053900
#
#           Amount
# Class
# 0.0    98.107837
# 1.0    93.992778
#
# [2 rows x 30 columns]

# %% [markdown]
# **Sampling**

# %% [markdown]
# Number of Fraudulent Transaction  ==> 198

# %%
legit_sam= legit.sample(n=198)

# %%
new_data = pd.concat([legit_sam, fraud], axis=0)

# %%
new_data.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 68982  53215 -0.930855  0.618318 -1.061594 -2.031645  2.473728  2.810930
# 63849  50893 -2.078104  1.899315 -0.025059 -0.072667 -0.312456 -0.861534
# 66404  52035 -0.496854  0.850741  1.425029  0.782065  0.135364 -0.658209
# 51742  45099  0.434136 -2.367642  0.545914 -0.159831 -1.889987  0.332338
# 42309  41048 -1.738309 -0.605169 -0.798154 -2.673771 -1.297856 -0.229840
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 68982  0.110320  1.211248 -0.668733  ...  0.019869 -0.276301 -0.023301
# 63849  0.026585  0.696012 -0.125416  ... -0.341320 -0.739334  0.183467
# 66404  0.717614 -0.144351 -0.319433  ...  0.117852  0.514386 -0.162258
# 51742 -0.652349  0.129417 -0.079976  ...  0.304596 -0.048567 -0.444477
# 42309  2.663275  0.180514  0.094228  ...  0.074102 -0.866277  1.188815
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 79835  58199  0.340391  2.015233 -2.777330  3.812024 -0.461729 -1.152022
# 79874  58217 -0.443794  1.271395  1.206178  0.790371  0.418935 -0.848376
# 79883  58222 -1.322789  1.552768 -2.276921  2.992117 -1.947064 -0.480288
# 80760  58642 -0.451383  2.225147 -4.953050  4.342228 -3.656190 -0.020121
# 81186  58822 -4.384221  3.264665 -3.077158  3.403594 -1.938075 -1.221081
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 79835 -2.001959  0.548681 -2.344042  ...  0.299769 -0.583283 -0.187696
# 79874  0.917691 -0.235511 -0.285692  ...  0.119279  0.513479 -0.264243
# 79883 -1.362388  0.953242 -2.329629  ...  0.614969 -0.195200  0.590711
# 80760 -5.407554 -0.748436 -1.362198  ... -0.575924  0.495889  1.154128
# 81186 -3.310317 -1.111975 -1.977593  ...  2.076383 -0.990303 -0.330358
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0.0    198
# 1.0    198
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    38401.318182 -0.300810 -0.107144  0.851902  0.200239 -0.093487
# 1.0    33363.156566 -6.471142  4.615004 -8.642655  5.163640 -4.726320
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.108502 -0.136297  0.036202 -0.083667  ...  0.087831  0.037348
# 1.0   -1.982527 -6.839513  3.005157 -3.106588  ...  0.381224  0.754921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.086193 -0.156282  0.002729  0.106682 -0.018461 -0.004284 -0.009212
# 1.0   -0.156429 -0.222226 -0.092181  0.229928  0.089311  0.568505  0.053900
#
#            Amount
# Class
# 0.0    103.592626
# 1.0     93.992778
#
# [2 rows x 30 columns]

# %% [markdown]
# *Modelling and Training*

# %%
X = new_data.drop(columns='Class', axis=1)
Y = new_data['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 68982  53215 -0.930855  0.618318 -1.061594 -2.031645  2.473728  2.810930
# 63849  50893 -2.078104  1.899315 -0.025059 -0.072667 -0.312456 -0.861534
# 66404  52035 -0.496854  0.850741  1.425029  0.782065  0.135364 -0.658209
# 51742  45099  0.434136 -2.367642  0.545914 -0.159831 -1.889987  0.332338
# 42309  41048 -1.738309 -0.605169 -0.798154 -2.673771 -1.297856 -0.229840
# ...      ...       ...       ...       ...       ...       ...       ...
# 79835  58199  0.340391  2.015233 -2.777330  3.812024 -0.461729 -1.152022
# 79874  58217 -0.443794  1.271395  1.206178  0.790371  0.418935 -0.848376
# 79883  58222 -1.322789  1.552768 -2.276921  2.992117 -1.947064 -0.480288
# 80760  58642 -0.451383  2.225147 -4.953050  4.342228 -3.656190 -0.020121
# 81186  58822 -4.384221  3.264665 -3.077158  3.403594 -1.938075 -1.221081
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 68982    0.0
# 63849    0.0
# 66404    0.0
# 51742    0.0
# 42309    0.0
#         ...
# 79835    1.0
# 79874    1.0
# 79883    1.0
# 80760    1.0
# 81186    1.0
# Name: Class, Length: 396, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (396, 30) (316, 30) (80, 30)

# %% [markdown]
# *Model Prediction*

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
train_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Training Data Acuracy:', train_data_accuracy)
# Out:
# Training Data Acuracy: 0.9588607594936709

# %%
x_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(x_test_prediction, Y_test)

# %%
print('Test Data Acuracy:', test_data_accuracy)
# Out:
# Test Data Acuracy: 0.925
